# %%
import matplotlib.pyplot as plt
n=[4,40,100,200,300,625]
Traditional=[0.000,0.001,0.005,0.44,0.147,1.114]
Strassen=[0.000,0.000,0.004,0.055,0.099,0.810]
plt.plot(n, Traditional, marker='o', label='Traditional Matrix Multiplication')
plt.plot(n, Strassen, marker='o', label='Strassen\'s Matrix Multiplication')


plt.xlabel('Matrix Size (n*n)')
plt.ylabel('Time (seconds)')
plt.title('Algorithm Performance Comparison')
plt.legend()
plt.grid(True)

plt.show()
